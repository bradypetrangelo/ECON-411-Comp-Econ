# %%
print("Hello world!")
# Out:
# Hello world!

# %%
type("Hello world!")
# Out:
# str

# %%
msg = "Hello world!"
print(msg)
# Out:
# Hello world!

# %%
type(msg)
# Out:
# str

# %%
msg = "john nash"

# ALL CAPS
msg_upper = msg.upper()
print(msg_upper)
# Capitalize the first letter of each word
msg_title = msg.title()
msg_title
# Out:
# JOHN NASH
# 'John Nash'

# %%
# Concatenate
print("A")
# Out:
# A

# %%
print("B")
# Out:
# B

# %%
print("A" + "B")
# Out:
# AB

# %%
a = "A"
b = "B"
print(a + b)
# Out:
# AB

# %%
line1 = "You thought it would be easy"
line2 = "You thought it wouldn't be strange"
line3 = "But then you started coding"
line4 = "Things never were the same"
print(line1 + line2 + line3 + line4)
print(line1 + " " + line2)
print(line1 + "\n" + line2)
print(line1, line2, line3, line4, sep = "\n")
# Out:
# You thought it would be easyYou thought it wouldn't be strangeBut then you started codingThings never were the same
# You thought it would be easy You thought it wouldn't be strange
# You thought it would be easy
# You thought it wouldn't be strange
# You thought it would be easy
# You thought it wouldn't be strange
# But then you started coding
# Things never were the same

# %%
# Quotes within quotes

# %%
# More string methods

# %%
space = "     Look at all the spaces in the text!       "
print(space)
# Out:
#      Look at all the spaces in the text!

# %%
# remove space on far left
print(space.lstrip())
# Out:
# Look at all the spaces in the text!

# %%
# remove space on far right
print(space.rstrip())
# Out:
#      Look at all the spaces in the text!

# %%
# remove space on both sides
print(space.strip())
# Out:
# Look at all the spaces in the text!

# %%
# remove all spaces
print(space.replace(" ", ""))
# Out:
# Lookatallthespacesinthetext!

# %%
print(space.replace("   ", "")
# Out:
#   File "/var/folders/36/1ps_njqs0_vg85qkr7w_tj440000gn/T/ipykernel_16169/2213394073.py", line 1
#     print(space.replace("   ", "")
#                                   ^
# SyntaxError: unexpected EOF while parsing

# %%
space.replace("s", "")
# Out:
# '     Look at all the pace in the text!       '

# %% [markdown]
# #Working with Numbers

# %%
print(1, 1.)
# Out:
# 1 1.0

# %%
int1 = 1
float1 = 1.
print(type(int1), type(float1)
      print(int1, float1)
# Out:
#   File "/var/folders/36/1ps_njqs0_vg85qkr7w_tj440000gn/T/ipykernel_16169/917632529.py", line 4
#     print(int1, float1)
#     ^
# SyntaxError: invalid syntax

# %%
int2 = int1 + int1
print(type(int2), int2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/36/1ps_njqs0_vg85qkr7w_tj440000gn/T/ipykernel_16169/1004812535.py in <module>
# ----> 1 int2 = int1 + int1
#       2 print(type(int2), int2)
#
# NameError: name 'int1' is not defined

# %%
float2 = int1 + float1
print(type(float2), float2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/36/1ps_njqs0_vg85qkr7w_tj440000gn/T/ipykernel_16169/1666086830.py in <module>
# ----> 1 float2 = int1 + float1
#       2 print(type(float2), float2)
#
# NameError: name 'int1' is not defined

# %%
## if you attempt to sum an int or float with a string an error results

# %%
int1 + str1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/36/1ps_njqs0_vg85qkr7w_tj440000gn/T/ipykernel_16169/2788647745.py in <module>
# ----> 1 int1 + str1
#
# NameError: name 'int1' is not defined

# %%
## Transform value to string

# %%
str11 = str(int1) + str1
str11
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/36/1ps_njqs0_vg85qkr7w_tj440000gn/T/ipykernel_16169/1097817162.py in <module>
# ----> 1 str11 = str(int1) + str1
#       2 str11
#
# NameError: name 'int1' is not defined

# %%
float2 = float(str1) + float1
float2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/36/1ps_njqs0_vg85qkr7w_tj440000gn/T/ipykernel_16169/4063495696.py in <module>
# ----> 1 float2 = float(str1) + float1
#       2 float2
#
# NameError: name 'str1' is not defined

# %%
total = ""
for i in range(20):
    total = total + str(i)
    print(total)
# Out:
# 0
# 01
# 012
# 0123
# 01234
# 012345
# 0123456
# 01234567
# 012345678
# 0123456789
# 012345678910
# 01234567891011
# 0123456789101112
# 012345678910111213
# 01234567891011121314
# 0123456789101112131415
# 012345678910111213141516
# 01234567891011121314151617
# 0123456789101112131415161718
# 012345678910111213141516171819

# %% [markdown]
# ## Use mathmatical operators + - / * =

# %%
1 + 1 - 1 / 1 * 1
# Out:
# 1.0

# %%
import sys
sys
# Out:
# <module 'sys' (built-in)>

# %%
# use .__dict__
sys.__dict__
# Out:
# {'__name__': 'sys',
# ...

# %%
dir(sys)
# Out:
# ['__breakpointhook__',
#  '__displayhook__',
#  '__doc__',
#  '__excepthook__',
#  '__interactivehook__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '__stderr__',
#  '__stdin__',
#  '__stdout__',
#  '__unraisablehook__',
#  '_base_executable',
#  '_clear_type_cache',
#  '_current_frames',
#  '_debugmallocstats',
#  '_framework',
#  '_getframe',
#  '_git',
#  '_home',
#  '_xoptions',
#  'abiflags',
#  'addaudithook',
#  'api_version',
#  'argv',
#  'audit',
#  'base_exec_prefix',
#  'base_prefix',
#  'breakpointhook',
#  'builtin_module_names',
#  'byteorder',
#  'call_tracing',
#  'copyright',
#  'displayhook',
#  'dont_write_bytecode',
#  'exc_info',
#  'excepthook',
#  'exec_prefix',
#  'executable',
#  'exit',
#  'flags',
#  'float_info',
#  'float_repr_style',
#  'get_asyncgen_hooks',
#  'get_coroutine_origin_tracking_depth',
#  'getallocatedblocks',
#  'getdefaultencoding',
#  'getdlopenflags',
#  'getfilesystemencodeerrors',
#  'getfilesystemencoding',
# ...

# %%
sys.float_info
# Out:
# sys.float_info(max=1.7976931348623157e+308, max_exp=1024, max_10_exp=308, min=2.2250738585072014e-308, min_exp=-1021, min_10_exp=-307, dig=15, mant_dig=53, epsilon=2.220446049250313e-16, radix=2, rounds=1)

# %%
sys.int_info
# Out:
# sys.int_info(bits_per_digit=30, sizeof_digit=4)

# %%
2.0 ** 1023
# Out:
# 8.98846567431158e+307

# %%
2.0 ** 1024
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# /var/folders/36/1ps_njqs0_vg85qkr7w_tj440000gn/T/ipykernel_16169/2834442352.py in <module>
# ----> 1 2.0 ** 1024
#
# OverflowError: (34, 'Result too large')

# %%
# amount of memory accepted by an int adjusts with the size of the int
10 ** 2000
# Out:
# ...
